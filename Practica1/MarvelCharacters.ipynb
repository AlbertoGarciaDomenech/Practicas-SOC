# %% [markdown]
# Autores: Eric Heresi Medina & Alberto García Doménech

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
nodos= pd.read_csv("nodos.csv")
nodos.sort_values('Degree', ascending = False).head(50)
# Out:
#         Id                 Label  timeset  Degree
# 1    10476   IRON MAN/TONY STARK      NaN    2189
# 40   10556       WOLVERINE/LOGAN      NaN    1984
# 35   10551       CAPTAIN AMERICA      NaN    1896
# 32   10541   SCARLET WITCH/WANDA      NaN    1883
# 42   10558                VISION      NaN    1765
# 55   10571   INVISIBLE WOMAN/SUE      NaN    1750
# 23   10532  SPIDER-MAN/PETER PAR      NaN    1730
# 26   10535   WASP/JANET VAN DYNE      NaN    1517
# 76   10638   DR. STRANGE/STEPHEN      NaN    1489
# 97   10679   PROFESSOR X/CHARLES      NaN    1471
# 54   10570  THING/BENJAMIN J. GR      NaN    1404
# 49   10565  MR. FANTASTIC/REED R      NaN    1368
# 111  10711   ICEMAN/ROBERT BOBBY      NaN    1354
# 117  10747  HUMAN TORCH/JOHNNY S      NaN    1349
# 160  10827         JARVIS, EDWIN      NaN    1303
# 72   10625  THOR/DR. DONALD BLAK      NaN    1281
# 257  11165   FURY, COL. NICHOLAS      NaN    1262
# 59   10575  BEAST/HENRY &HANK& P      NaN    1259
# ...

# %%
aristas = pd.read_csv("Aristas.csv")
aristas
# Out:
#         Source  Target        Type      Id  Label  timeset  Weight
# 0        10470   10476  Undirected  257707    NaN      NaN       1
# 1        10470   10613  Undirected  257708    NaN      NaN       1
# 2        10470   10625  Undirected  257706    NaN      NaN       1
# 3        10470   10827  Undirected  257710    NaN      NaN       1
# 4        10470   11508  Undirected  251494    NaN      NaN       1
# ...        ...     ...         ...     ...    ...      ...     ...
# 178110   20935   10953  Undirected  402178    NaN      NaN       1
# 178111   20935   11835  Undirected  402182    NaN      NaN       1
# 178112   20935   14465  Undirected  402181    NaN      NaN       1
# 178113   20935   18504  Undirected  402177    NaN      NaN       1
# 178114   20935   18505  Undirected  402180    NaN      NaN       1
#
# [178115 rows x 7 columns]

# %%
nodos = nodos.drop(["timeset"], axis=1)
nodos.head()
nodos = nodos.sort_values('Degree', ascending = False)
nodos
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c118d633917d> in <module>
# ----> 1 nodos = nodos.drop(["timeset"], axis=1)
#       2 nodos.head()
#       3 nodos = nodos.sort_values('degree', ascending = False)
#       4 nodos
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
first1000 = nodos[0:1000]
first1000

# %%
names = first1000['Label']
id = first1000['Id']
degree = first1000['degree']

# %%
aristas['Source'][423]
# Out:
# 10476

# %%
# 10476 in first1000['Id']
first1000['Id'][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-b24bc0efd18d> in <module>
#       1 # 10476 in first1000['Id']
# ----> 2 first1000['Id'][1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
filterA = pd.DataFrame()
for a in aristas['Source']:
    if (a in first1000['Id']):
        print(a)
#         filterA.append(a)

# %%
aristas = pd.read_csv("Aristas2.csv")
aristas.head()
# Out:
#    Source  Target        Type      Id  Label  timeset  Weight
# 0   10470   10476  Undirected  257707    NaN      NaN       1
# 1   10470   10613  Undirected  257708    NaN      NaN       1
# 2   10470   10625  Undirected  257706    NaN      NaN       1
# 3   10470   10827  Undirected  257710    NaN      NaN       1
# 4   10470   11508  Undirected  251494    NaN      NaN       1

# %%
aristas['Source'][423]
# Out:
# 10476
